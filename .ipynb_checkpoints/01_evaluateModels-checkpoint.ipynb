# %%
# Make the notebook wider 
from IPython.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

# %load_ext autoreload
# %autoreload 2
# Out:
# <style>.container { width:80% !important; }</style>

# %% [markdown]
# <br>
# <div style="text-align: left; font-family: Arial, sans-serif; color: #003366;">
#     <font size=9><b>Step 1: Compare Different Models with Different Sets of Input Features</b></font>
# </div>
# <br>
#
# The objective of this step is to identify the most effective combination of:
#
# <ul>
#   <li><b>Input features</b> — it is not guaranteed that using all available predictors improves performance.</li>
#   <li><b>Model type</b> — comparing both <b>linear</b> and <b>non-linear</b> regressors.</li>
#   <li><b>Hyperparameter values</b> — values that must be set before training a model and that will influence its performance.</li>
# </ul>
#
# <br>
#
# To achieve this, we perform an extensive <span style="color:#003366"><b>cross-validation</b></span> procedure. This ensures that model evaluation is <b>robust</b>, <b>comparable</b>, and <b>generalizable</b>, preventing overfitting to any specific data subset.
#
# All numerical variables, as well as the target <span style="color:#003366"><b>Die_area</b></span>, are analyzed in <b>log scale</b>.<br><br>
#
# <div style="background-color: #ffffff; padding: 12px; border-left: 5px solid #003366; margin-top: 10px;">
# 💡 <b>Note:</b> The cross-validation procedure is performed exclusively on the data from the <b>train set</b>.
# </div>
# <br><br>

# %%
import os
import pandas as pd
import numpy as np
from itertools import combinations

from Utils.loadData import load_and_prepare_data
from Utils.crossValidation import evaluate_models_with_grid_search


#######################################################################################################
# HELPER FUNCTION — Convert parameter dictionary to filename
#######################################################################################################
def param_dict_to_filename(params):
    """
    Convert a parameter dictionary into a descriptive filename.
    Example:
        {"features": ["M", "P_area"]} → "features-[M,P_area].csv"
    """
    parts = []
    for key, value in params.items():
        if isinstance(value, list):
            val_str = "[" + ",".join(map(str, value)) + "]"
        else:
            val_str = str(value)
        parts.append(f"{key}-{val_str}")
    return "_".join(parts) + ".csv"


#######################################################################################################
# MAIN FUNCTION — Run all grid searches and save results
#######################################################################################################
def run_all_grid_searches(df_train, df_test, all_features, resFolder="CVRuns"):
    """
    Run grid searches for all feature combinations and save cross-validation summaries to disk.
    """
    # Generate all possible feature combinations
    feature_combinations = [
        list(c) for k in range(1, len(all_features) + 1)
        for c in combinations(all_features, k)
    ]

    # Iterate over each feature set
    for combi in feature_combinations:
        params = {"features": combi}
        print(f"--- Running grid search for features: {combi}")

        summary_df = evaluate_models_with_grid_search(df_train, **params)

        # Save CSV without prefix
        filename = os.path.join(resFolder, param_dict_to_filename(params))
        summary_df.to_csv(filename, index=False)

    print(f"\nAll grid search results saved in: {resFolder}")


#######################################################################################################
# DATA PREPARATION
#######################################################################################################
df_train, df_test = load_and_prepare_data("Data/dataset.xlsx")
all_features      = ["M", "P_area", "Pin_count", "P_type"]
resFolder         = "CVRuns"  # Output folder
os.makedirs(resFolder, exist_ok=True)


# ----------------------------------------------------------------------------------------------------
# RUN CROSS-VALIDATION
# ----------------------------------------------------------------------------------------------------
# To execute the full benchmark, uncomment the line below. It will train all models across all feature subsets and save their summaries.

#run_all_grid_searches(df_train, df_test, all_features, resFolder=resFolder)

# %%
from Utils.printResults import display_final_table
display_final_table(df_train, df_test, all_features, folder="CVRuns")
# Out:
# <style type="text/css">
# #T_861cd th {
#   white-space: pre-line;
#   text-align: center;
# }
# #T_861cd td {
#   text-align: center;
# }
# #T_861cd_row0_col2, #T_861cd_row1_col3, #T_861cd_row2_col4, #T_861cd_row3_col5, #T_861cd_row4_col2, #T_861cd_row4_col4, #T_861cd_row5_col2, #T_861cd_row5_col5, #T_861cd_row6_col2, #T_861cd_row6_col3, #T_861cd_row7_col3, #T_861cd_row7_col4, #T_861cd_row8_col3, #T_861cd_row8_col5, #T_861cd_row9_col4, #T_861cd_row9_col5, #T_861cd_row10_col2, #T_861cd_row10_col3, #T_861cd_row10_col5, #T_861cd_row11_col2, #T_861cd_row11_col4, #T_861cd_row11_col5, #T_861cd_row12_col2, #T_861cd_row12_col3, #T_861cd_row12_col4, #T_861cd_row13_col3, #T_861cd_row13_col4, #T_861cd_row13_col5, #T_861cd_row14_col2, #T_861cd_row14_col3, #T_861cd_row14_col4, #T_861cd_row14_col5 {
#   font-weight: bold;
#   color: black;
# }
# #T_861cd_row0_col6 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_861cd_row0_col7 {
#   background-color: #fdcbb6;
#   color: #000000;
# }
# #T_861cd_row0_col8, #T_861cd_row0_col9, #T_861cd_row1_col8, #T_861cd_row1_col9, #T_861cd_row2_col8, #T_861cd_row2_col9, #T_861cd_row4_col8, #T_861cd_row4_col9, #T_861cd_row6_col8, #T_861cd_row6_col9, #T_861cd_row7_col8, #T_861cd_row7_col9, #T_861cd_row12_col8, #T_861cd_row12_col9 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: lightgray;
# }
# #T_861cd_row0_col10 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_861cd_row0_col11 {
#   background-color: #f34c37;
#   color: #f1f1f1;
# }
# #T_861cd_row0_col12 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_861cd_row0_col13, #T_861cd_row3_col7, #T_861cd_row3_col9, #T_861cd_row3_col11, #T_861cd_row3_col15, #T_861cd_row3_col17 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_861cd_row0_col14 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_861cd_row0_col15 {
#   background-color: #fc9070;
#   color: #000000;
# }
# #T_861cd_row0_col16 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_861cd_row0_col17 {
#   background-color: #fcb89e;
#   color: #000000;
# }
# #T_861cd_row1_col6, #T_861cd_row1_col16 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_861cd_row1_col7 {
#   background-color: #f75b40;
#   color: #f1f1f1;
# }
# #T_861cd_row1_col10 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_861cd_row1_col11, #T_861cd_row6_col15 {
#   background-color: #d32020;
#   color: #f1f1f1;
# }
# #T_861cd_row1_col12 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_861cd_row1_col13 {
#   background-color: #fcc4ad;
#   color: #000000;
# }
# #T_861cd_row1_col14 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_861cd_row1_col15 {
#   background-color: #dd2a25;
#   color: #f1f1f1;
# }
# #T_861cd_row1_col17 {
#   background-color: #ee3a2c;
#   color: #f1f1f1;
# }
# #T_861cd_row2_col6, #T_861cd_row5_col8 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_861cd_row2_col7, #T_861cd_row9_col7 {
#   background-color: #b61319;
#   color: #f1f1f1;
# }
# #T_861cd_row2_col10 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_861cd_row2_col11 {
#   background-color: #f75c41;
#   color: #f1f1f1;
# }
# #T_861cd_row2_col12, #T_861cd_row5_col12 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_861cd_row2_col13, #T_861cd_row8_col17, #T_861cd_row10_col9, #T_861cd_row13_col7, #T_861cd_row13_col11, #T_861cd_row13_col15 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_861cd_row2_col14, #T_861cd_row6_col6, #T_861cd_row6_col14 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_861cd_row2_col15, #T_861cd_row9_col17 {
#   background-color: #a91016;
#   color: #f1f1f1;
# }
# #T_861cd_row2_col16 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_861cd_row2_col17, #T_861cd_row11_col7, #T_861cd_row11_col13 {
#   background-color: #ad1117;
#   color: #f1f1f1;
# }
# #T_861cd_row3_col6, #T_861cd_row3_col8, #T_861cd_row3_col10, #T_861cd_row3_col12, #T_861cd_row3_col14, #T_861cd_row3_col16 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_861cd_row3_col13 {
#   background-color: #fdc9b3;
#   color: #000000;
# }
# #T_861cd_row4_col6, #T_861cd_row12_col10 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_861cd_row4_col7 {
#   background-color: #b31218;
#   color: #f1f1f1;
# }
# #T_861cd_row4_col10 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_861cd_row4_col11, #T_861cd_row9_col13 {
#   background-color: #71020e;
#   color: #f1f1f1;
# }
# #T_861cd_row4_col12 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_861cd_row4_col13 {
#   background-color: #e83429;
#   color: #f1f1f1;
# }
# #T_861cd_row4_col14 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_861cd_row4_col15 {
#   background-color: #9a0c14;
#   color: #f1f1f1;
# }
# #T_861cd_row4_col16, #T_861cd_row12_col14 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_861cd_row4_col17, #T_861cd_row5_col11 {
#   background-color: #af1117;
#   color: #f1f1f1;
# }
# #T_861cd_row5_col6 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_861cd_row5_col7 {
#   background-color: #f0402f;
#   color: #f1f1f1;
# }
# #T_861cd_row5_col9, #T_861cd_row5_col13 {
#   background-color: #f14130;
#   color: #f1f1f1;
# }
# #T_861cd_row5_col10, #T_861cd_row11_col16 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_861cd_row5_col14 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_861cd_row5_col15, #T_861cd_row11_col9 {
#   background-color: #c8171c;
#   color: #f1f1f1;
# }
# #T_861cd_row5_col16 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_861cd_row5_col17 {
#   background-color: #d82422;
#   color: #f1f1f1;
# }
# #T_861cd_row6_col7, #T_861cd_row13_col13 {
#   background-color: #f24633;
#   color: #f1f1f1;
# }
# #T_861cd_row6_col10 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_861cd_row6_col11 {
#   background-color: #9f0e14;
#   color: #f1f1f1;
# }
# #T_861cd_row6_col12 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_861cd_row6_col13, #T_861cd_row14_col13 {
#   background-color: #c3161b;
#   color: #f1f1f1;
# }
# #T_861cd_row6_col16 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_861cd_row6_col17 {
#   background-color: #f34935;
#   color: #f1f1f1;
# }
# #T_861cd_row7_col6 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_861cd_row7_col7 {
#   background-color: #b21218;
#   color: #f1f1f1;
# }
# #T_861cd_row7_col10, #T_861cd_row11_col12 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_861cd_row7_col11, #T_861cd_row7_col15, #T_861cd_row8_col9 {
#   background-color: #73030f;
#   color: #f1f1f1;
# }
# #T_861cd_row7_col12 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_861cd_row7_col13 {
#   background-color: #da2723;
#   color: #f1f1f1;
# }
# #T_861cd_row7_col14 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_861cd_row7_col16 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_861cd_row7_col17 {
#   background-color: #a10e15;
#   color: #f1f1f1;
# }
# #T_861cd_row8_col6, #T_861cd_row8_col14 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_861cd_row8_col7, #T_861cd_row13_col9, #T_861cd_row13_col17 {
#   background-color: #69000d;
#   color: #f1f1f1;
# }
# #T_861cd_row8_col8, #T_861cd_row13_col6 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_861cd_row8_col10 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_861cd_row8_col11 {
#   background-color: #980c13;
#   color: #f1f1f1;
# }
# #T_861cd_row8_col12 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_861cd_row8_col13 {
#   background-color: #c7171c;
#   color: #f1f1f1;
# }
# #T_861cd_row8_col15 {
#   background-color: #79040f;
#   color: #f1f1f1;
# }
# #T_861cd_row8_col16, #T_861cd_row10_col6, #T_861cd_row13_col8, #T_861cd_row13_col12, #T_861cd_row13_col14, #T_861cd_row14_col10 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_861cd_row9_col6, #T_861cd_row9_col8 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_861cd_row9_col9 {
#   background-color: #b01217;
#   color: #f1f1f1;
# }
# #T_861cd_row9_col10 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_861cd_row9_col11 {
#   background-color: #bf151b;
#   color: #f1f1f1;
# }
# #T_861cd_row9_col12 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_861cd_row9_col14 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_861cd_row9_col15 {
#   background-color: #b51318;
#   color: #f1f1f1;
# }
# #T_861cd_row9_col16 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_861cd_row10_col7, #

# %% [markdown]
# <div style="border: 2px solid steelblue; border-radius: 8px; padding: 15px; background-color: #f0f8ff; font-family: Arial, sans-serif;">
#
# <b>Understanding RMSE — The Root Mean Squared Error</b><br><br>
#
# The <b>Root Mean Squared Error (RMSE)</b> is the primary metric used to evaluate model performance in this notebook.
# It quantifies the average magnitude of prediction errors — that is, how far the predicted values are from the observed ones.
#
# <br><br>
#
# The RMSE is defined as:
#
# <div style="text-align:center; font-size: 16px; margin-top:10px; margin-bottom:10px;">
#   $$ \mathrm{RMSE} = \sqrt{ \frac{1}{n} \sum_{i=1}^{n} (\hat{y}_i - y_i)^2 } $$
# </div>
#
# $$
# \text{where } \hat{y}_i \text{ and } y_i \text{ represent the predicted and observed values, respectively.}
# $$
#
# <ul>
#   <li><b>Lower RMSE</b> values indicate better model performance.</li>
#   <li><b>RMSE = 0</b> means perfect prediction (no deviation from observed data).</li>
#   <li>Because RMSE is expressed in the same units as the target variable, it directly reflects the prediction accuracy.</li>
# </ul>
#
# <br>
#
# <b>RMSE in Log-Log Space</b><br>
#
# This means RMSE measures the <b>average deviation between predicted and true log(Die area)</b> values.
# Because the model operates in logarithmic space, the RMSE represents a <b>multiplicative error</b> on the original scale:
#
# <ul>
#   <li>An RMSE of <b>0.1</b> corresponds to predictions differing by roughly a factor of 10⁰·¹ ≈ <b>1.26</b>.</li>
#   <li>An RMSE of <b>0.3</b> corresponds to a factor of 10⁰·³ ≈ <b>2</b>, meaning predicted die areas differ by about a factor of two on average.</li>
# </ul>
#
# <div style="background-color: #ffffff; padding: 12px; border-left: 5px solid #cc5500; margin-top: 10px;">
#   ⚠️ <b>Important:</b> RMSE in log space emphasizes <i>relative accuracy</i> rather than absolute error.
#   A model with low log-RMSE provides consistent proportional predictions even if large dies have larger absolute differences.
# </div>
#
# </div>
# <br><br>

# %% [markdown]
# <br>
# <div style="text-align: left; font-family: Arial, sans-serif; color: #003366;">
#     <font size=9><b>Step 2: Visualize some models</b></font>
# </div>
# <br>

# %%
from MakeGraphs.plotModels import refit_and_plot_univariate  
from Utils.crossValidation import refit_models

df_train, df_test = load_and_prepare_data("Data/dataset.xlsx")
features = ["P_area"] 
summary_df = evaluate_models_with_grid_search(df_train, features=features)

final_summary, trained_models, (X_train, y_train, X_test, y_test) = refit_models(df_train, df_test, summary_df, features=features)

# Then just call:
refit_and_plot_univariate(
    trained_models,
    X_train, y_train,
    X_test, y_test,
    feature="P_area",   # the univariate feature to plot
    log_log=True        # True = log–log plot (for consistency)
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 from Utils.plotModels import refit_and_plot_univariate
#       2 from Utils.crossValidation import refit_models
#       4 df_train, df_test = load_and_prepare_data("Data/dataset.xlsx")
#
# ModuleNotFoundError: No module named 'Utils.plotModels'
